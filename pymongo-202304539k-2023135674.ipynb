# %%
from pymongo import MongoClient

# Cadena de conexión al Replica Set
uri = "mongodb://mongo1:30001,mongo2:30002,mongo3:30003/?replicaSet=my-replica-set"

try:
    client = MongoClient(uri, serverSelectionTimeoutMS=5000)
    db = client["Politica"]
    print("Conexión exitosa. Colecciones actuales:", db.list_collection_names())
except Exception as e:
    print("Error al conectar:", e)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pymongo import MongoClient
#       3 # Cadena de conexión al Replica Set
#       4 uri = "mongodb://mongo1:30001,mongo2:30002,mongo3:30003/?replicaSet=my-replica-set"
#
# ModuleNotFoundError: No module named 'pymongo'

# %%
from pymongo import MongoClient
print("pymongo funciona")
# Out:
# pymongo funciona

# %%
from pymongo import MongoClient

uri = "mongodb://mongo1:30001,mongo2:30002,mongo3:30003/?replicaSet=my-replica-set"

try:
    client = MongoClient(uri, serverSelectionTimeoutMS=5000)
    print("Conexión establecida con el cluster ✨")
    print("Estado del cluster:", client.admin.command("hello"))
except Exception as e:
    print("Error:", e)
# Out:
# Conexión establecida con el cluster ✨
# Estado del cluster: {'topologyVersion': {'processId': ObjectId('69160080a6d1b5adc317ad26'), 'counter': 7}, 'hosts': ['mongo1:30001', 'mongo2:30002', 'mongo3:30003'], 'setName': 'my-replica-set', 'setVersion': 1, 'isWritablePrimary': True, 'secondary': False, 'primary': 'mongo1:30001', 'me': 'mongo1:30001', 'electionId': ObjectId('7fffffff0000000000000003'), 'lastWrite': {'opTime': {'ts': Timestamp(1763144953, 1), 't': 3}, 'lastWriteDate': datetime.datetime(2025, 11, 14, 18, 29, 13), 'majorityOpTime': {'ts': Timestamp(1763144953, 1), 't': 3}, 'majorityWriteDate': datetime.datetime(2025, 11, 14, 18, 29, 13)}, 'maxBsonObjectSize': 16777216, 'maxMessageSizeBytes': 48000000, 'maxWriteBatchSize': 100000, 'localTime': datetime.datetime(2025, 11, 14, 18, 29, 15, 87000), 'logicalSessionTimeoutMinutes': 30, 'connectionId': 2354, 'minWireVersion': 0, 'maxWireVersion': 13, 'readOnly': False, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1763144953, 1), 'signature': {'hash': b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00', 'keyId': 0}}, 'operationTime': Timestamp(1763144953, 1)}
